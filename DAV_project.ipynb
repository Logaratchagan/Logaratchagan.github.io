# %% [markdown]
# <a href="https://colab.research.google.com/github/Logaratchagan/Logaratchagan.github.io/blob/main/DAV_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **DATA ANALYSIS OF AIRLINE PASSENGERS SATISFACTION**

# %% [markdown]
# **Analysing the passenger satisfaction report from the Japan Airlines which helps us in improving services**

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
ds = pd.read_csv('/content/drive/MyDrive/Airline passenger satisfaction.csv')
ds
# Out:
#        Unnamed: 0     id  Gender      Customer_Type  Age   Type_of_Travel  \
# 0               0  19556  Female     Loyal Customer   52  Business travel
# 1               1  90035  Female     Loyal Customer   36  Business travel
# 2               2  12360    Male  disloyal Customer   20  Business travel
# 3               3  77959    Male     Loyal Customer   44  Business travel
# 4               4  36875  Female     Loyal Customer   49  Business travel
# ...           ...    ...     ...                ...  ...              ...
# 25971       25971  78463    Male  disloyal Customer   34  Business travel
# 25972       25972  71167    Male     Loyal Customer   23  Business travel
# 25973       25973  37675  Female     Loyal Customer   17  Personal Travel
# 25974       25974  90086    Male     Loyal Customer   14  Business travel
# 25975       25975  34799  Female     Loyal Customer   42  Personal Travel
#
#           Class  Flight_Distance  Inflight_wifi_service  \
# ...

# %% [markdown]
# **Original** **Dataset**

# %%
ds.shape
# Out:
# (25976, 25)

# %% [markdown]
# To find the shape of the dataset which includes the (row , column)

# %%
ds1 = ds.iloc[:,1:]
ds1
# Out:
#           id  Gender      Customer_Type  Age   Type_of_Travel     Class  \
# 0      19556  Female     Loyal Customer   52  Business travel       Eco
# 1      90035  Female     Loyal Customer   36  Business travel  Business
# 2      12360    Male  disloyal Customer   20  Business travel       Eco
# 3      77959    Male     Loyal Customer   44  Business travel  Business
# 4      36875  Female     Loyal Customer   49  Business travel       Eco
# ...      ...     ...                ...  ...              ...       ...
# 25971  78463    Male  disloyal Customer   34  Business travel  Business
# 25972  71167    Male     Loyal Customer   23  Business travel  Business
# 25973  37675  Female     Loyal Customer   17  Personal Travel       Eco
# 25974  90086    Male     Loyal Customer   14  Business travel  Business
# 25975  34799  Female     Loyal Customer   42  Personal Travel       Eco
#
#        Flight_Distance  Inflight_wifi_service  \
# 0                  160                      5
# ...

# %% [markdown]
# We are excluding the first row named as 'unnamed' avoiding that row we are using the slicing

# %%
ds1.dtypes
# Out:
# id                                     int64
# Gender                                object
# Customer_Type                         object
# Age                                    int64
# Type_of_Travel                        object
# Class                                 object
# Flight_Distance                        int64
# Inflight_wifi_service                  int64
# Departure/Arrival_time_convenient      int64
# Ease_of_Online_booking                 int64
# Gate_location                          int64
# Food_and_drink                         int64
# Online_boarding                        int64
# Seat_comfort                           int64
# Inflight_entertainment                 int64
# Onboard_service                        int64
# Legroom_service                        int64
# Baggage_handling                       int64
# Checkin_service                        int64
# Inflight_service                       int64
# Cleanliness                            int64
# ...

# %% [markdown]
# To check the datatypes present in the respective dataset

# %% [markdown]
# # **Converting the Object datatype to Category datatype for reducing the data usage**

# %%
ds1['Gender' ] = ds1['Gender'].astype('category')
ds1['id'] = ds1['id'].astype('int8')
ds1['Age'] = ds1['Age'].astype('int8')
ds1['Customer_Type' ] = ds1['Customer_Type'].astype('category')
ds1['Type_of_Travel' ] = ds1['Type_of_Travel'].astype('category')
ds1['Class' ] = ds1['Class'].astype('category')
ds1['satisfaction' ] = ds1['satisfaction'].astype('category')

# %% [markdown]
# We are converting the object data type into the category data type because the object datatype holds more space comparing to other data type

# %%
ds1.dtypes
# Out:
# id                                       int8
# Gender                               category
# Customer_Type                        category
# Age                                      int8
# Type_of_Travel                       category
# Class                                category
# Flight_Distance                         int64
# Inflight_wifi_service                   int64
# Departure/Arrival_time_convenient       int64
# Ease_of_Online_booking                  int64
# Gate_location                           int64
# Food_and_drink                          int64
# Online_boarding                         int64
# Seat_comfort                            int64
# Inflight_entertainment                  int64
# Onboard_service                         int64
# Legroom_service                         int64
# Baggage_handling                        int64
# Checkin_service                         int64
# Inflight_service                        int64
# ...

# %% [markdown]
# Checking whether the datatype is changed or not in the dataset

# %%
ds1.memory_usage()
# Out:
# Index                                   128
# id                                    25976
# Gender                                26100
# Customer_Type                         26100
# Age                                   25976
# Type_of_Travel                        26100
# Class                                 26108
# Flight_Distance                      207808
# Inflight_wifi_service                207808
# Departure/Arrival_time_convenient    207808
# Ease_of_Online_booking               207808
# Gate_location                        207808
# Food_and_drink                       207808
# Online_boarding                      207808
# Seat_comfort                         207808
# Inflight_entertainment               207808
# Onboard_service                      207808
# Legroom_service                      207808
# Baggage_handling                     207808
# Checkin_service                      207808
# Inflight_service                     207808
# ...

# %% [markdown]
# Memory allocated for each and every row in the dataset

# %%
ds1[ds1.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, Gender, Customer_Type, Age, Type_of_Travel, Class, Flight_Distance, Inflight_wifi_service, Departure/Arrival_time_convenient, Ease_of_Online_booking, Gate_location, Food_and_drink, Online_boarding, Seat_comfort, Inflight_entertainment, Onboard_service, Legroom_service, Baggage_handling, Checkin_service, Inflight_service, Cleanliness, Departure_Delay_in_Minutes, Arrival_Delay_in_Minutes, satisfaction]
# Index: []
#
# [0 rows x 24 columns]

# %% [markdown]
# Checking any rows are duplicated in the dataset with same values

# %%
ds1 = ds.drop('Unnamed: 0', axis= 1, );ds1
# Out:
#           id  Gender      Customer_Type  Age   Type_of_Travel     Class  \
# 0      19556  Female     Loyal Customer   52  Business travel       Eco
# 1      90035  Female     Loyal Customer   36  Business travel  Business
# 2      12360    Male  disloyal Customer   20  Business travel       Eco
# 3      77959    Male     Loyal Customer   44  Business travel  Business
# 4      36875  Female     Loyal Customer   49  Business travel       Eco
# ...      ...     ...                ...  ...              ...       ...
# 25971  78463    Male  disloyal Customer   34  Business travel  Business
# 25972  71167    Male     Loyal Customer   23  Business travel  Business
# 25973  37675  Female     Loyal Customer   17  Personal Travel       Eco
# 25974  90086    Male     Loyal Customer   14  Business travel  Business
# 25975  34799  Female     Loyal Customer   42  Personal Travel       Eco
#
#        Flight_Distance  Inflight_wifi_service  \
# 0                  160                      5
# ...

# %% [markdown]
# Deleting the unwanted row in the dataset

# %%
ds1.columns
# Out:
# Index(['id', 'Gender', 'Customer_Type', 'Age', 'Type_of_Travel', 'Class',
#        'Flight_Distance', 'Inflight_wifi_service',
#        'Departure/Arrival_time_convenient', 'Ease_of_Online_booking',
#        'Gate_location', 'Food_and_drink', 'Online_boarding', 'Seat_comfort',
#        'Inflight_entertainment', 'Onboard_service', 'Legroom_service',
#        'Baggage_handling', 'Checkin_service', 'Inflight_service',
#        'Cleanliness', 'Departure_Delay_in_Minutes', 'Arrival_Delay_in_Minutes',
#        'satisfaction'],
#       dtype='object')

# %%
ds2 = ds1.rename({'Customer_Type': 'Customer','Type_of_Travel':'Type','Flight_Distance': 'Distance','Inflight_wifi_service': 'Wifi',
'Departure/Arrival_time_convenient': 'Departure','Ease_of_Online_booking': 'Online', 'Inflight_entertainment':'Entertainment'}, axis=1); ds1
# Out:
#           id  Gender      Customer_Type  Age   Type_of_Travel     Class  \
# 0      19556  Female     Loyal Customer   52  Business travel       Eco
# 1      90035  Female     Loyal Customer   36  Business travel  Business
# 2      12360    Male  disloyal Customer   20  Business travel       Eco
# 3      77959    Male     Loyal Customer   44  Business travel  Business
# 4      36875  Female     Loyal Customer   49  Business travel       Eco
# ...      ...     ...                ...  ...              ...       ...
# 25971  78463    Male  disloyal Customer   34  Business travel  Business
# 25972  71167    Male     Loyal Customer   23  Business travel  Business
# 25973  37675  Female     Loyal Customer   17  Personal Travel       Eco
# 25974  90086    Male     Loyal Customer   14  Business travel  Business
# 25975  34799  Female     Loyal Customer   42  Personal Travel       Eco
#
#        Flight_Distance  Inflight_wifi_service  \
# 0                  160                      5
# ...

# %% [markdown]
# Changing the name of the columns using the rename function

# %%
ds2
# Out:
#           id  Gender           Customer  Age             Type     Class  \
# 0      19556  Female     Loyal Customer   52  Business travel       Eco
# 1      90035  Female     Loyal Customer   36  Business travel  Business
# 2      12360    Male  disloyal Customer   20  Business travel       Eco
# 3      77959    Male     Loyal Customer   44  Business travel  Business
# 4      36875  Female     Loyal Customer   49  Business travel       Eco
# ...      ...     ...                ...  ...              ...       ...
# 25971  78463    Male  disloyal Customer   34  Business travel  Business
# 25972  71167    Male     Loyal Customer   23  Business travel  Business
# 25973  37675  Female     Loyal Customer   17  Personal Travel       Eco
# 25974  90086    Male     Loyal Customer   14  Business travel  Business
# 25975  34799  Female     Loyal Customer   42  Personal Travel       Eco
#
#        Distance  Wifi  Departure  Online  ...  Entertainment  Onboard_service  \
# ...

# %%
ds2.isnull().sum()
# Out:
# id                             0
# Gender                         0
# Customer                       0
# Age                            0
# Type                           0
# Class                          0
# Distance                       0
# Wifi                           0
# Departure                      0
# Online                         0
# Gate_location                  0
# Food_and_drink                 0
# Online_boarding                0
# Seat_comfort                   0
# Entertainment                  0
# Onboard_service                0
# Legroom_service                0
# Baggage_handling               0
# Checkin_service                0
# Inflight_service               0
# Cleanliness                    0
# Departure_Delay_in_Minutes     0
# Arrival_Delay_in_Minutes      83
# satisfaction                   0
# dtype: int64

# %% [markdown]
# Checking for the null value in the column

# %%
ds2['Arrival_Delay_in_Minutes']
# Out:
# 0        44.0
# 1         0.0
# 2         0.0
# 3         6.0
# 4        20.0
#          ...
# 25971     0.0
# 25972     0.0
# 25973     0.0
# 25974     0.0
# 25975     0.0
# Name: Arrival_Delay_in_Minutes, Length: 25976, dtype: float64

# %% [markdown]
# Only 86 flights are having the NaN values so applying '0' for those values

# %%
ds2['Arrival_Delay_in_Minutes'] = ds2['Arrival_Delay_in_Minutes'].fillna(0)

# %% [markdown]
# Filling the mean value in the dataset for the respective column

# %%
ds2['Arrival_Delay_in_Minutes']
# Out:
# 0        44.0
# 1         0.0
# 2         0.0
# 3         6.0
# 4        20.0
#          ...
# 25971     0.0
# 25972     0.0
# 25973     0.0
# 25974     0.0
# 25975     0.0
# Name: Arrival_Delay_in_Minutes, Length: 25976, dtype: float64

# %% [markdown]
# Checking the column

# %%
ds2.isnull().sum()
# Out:
# id                            0
# Gender                        0
# Customer                      0
# Age                           0
# Type                          0
# Class                         0
# Distance                      0
# Wifi                          0
# Departure                     0
# Online                        0
# Gate_location                 0
# Food_and_drink                0
# Online_boarding               0
# Seat_comfort                  0
# Entertainment                 0
# Onboard_service               0
# Legroom_service               0
# Baggage_handling              0
# Checkin_service               0
# Inflight_service              0
# Cleanliness                   0
# Departure_Delay_in_Minutes    0
# Arrival_Delay_in_Minutes      0
# satisfaction                  0
# dtype: int64

# %% [markdown]
# Checking for the null values in the dataset after changing it

# %%
ds2.head(15)
# Out:
#         id  Gender           Customer  Age             Type     Class  \
# 0    19556  Female     Loyal Customer   52  Business travel       Eco
# 1    90035  Female     Loyal Customer   36  Business travel  Business
# 2    12360    Male  disloyal Customer   20  Business travel       Eco
# 3    77959    Male     Loyal Customer   44  Business travel  Business
# 4    36875  Female     Loyal Customer   49  Business travel       Eco
# 5    39177    Male     Loyal Customer   16  Business travel       Eco
# 6    79433  Female     Loyal Customer   77  Business travel  Business
# 7    97286  Female     Loyal Customer   43  Business travel  Business
# 8    27508    Male     Loyal Customer   47  Business travel       Eco
# 9    62482  Female     Loyal Customer   46  Business travel  Business
# 10   47583  Female     Loyal Customer   47  Business travel       Eco
# 11  115550  Female     Loyal Customer   33  Business travel  Business
# ...

# %% [markdown]
# Fetching the First fifteen entries in the dataset

# %%
ds2.columns
# Out:
# Index(['id', 'Gender', 'Customer', 'Age', 'Type', 'Class', 'Distance', 'Wifi',
#        'Departure', 'Online', 'Gate_location', 'Food_and_drink',
#        'Online_boarding', 'Seat_comfort', 'Entertainment', 'Onboard_service',
#        'Legroom_service', 'Baggage_handling', 'Checkin_service',
#        'Inflight_service', 'Cleanliness', 'Departure_Delay_in_Minutes',
#        'Arrival_Delay_in_Minutes', 'satisfaction'],
#       dtype='object')

# %% [markdown]
# These are the columns present in the Airline Passenger Satisfaction and all the information present is about the passengers only
#
# ( ID, Gender,Customer,Age,Type, Class,Distance,Wifi,Departure, Online, Gate_location, Food_and_drink,Online_boarding, Seat_comfort,Entertainment,Onboard_service,Legroom_service,Baggage_handling, Checkin_service,Inflight_service,Cleanliness, Departure_Delay_in_Minutes, Arrival_Delay_in_Minutes, Satisfaction)
#
# ID                      -> ID of the passengers
#
# Gender                  -> Gender of the passengers
#
# Customer Type           -> It gives the details about the type of customers (Loyal and disloyal)
#
# Age                     -> Age of the passenger
#
# Type                    -> Purpose of travelling
#
# Class                   -> Class preferred
#
# Flight Distance         -> Distance Travelled
#
# Inflight Wifi service   -> Rating about the Inflight Wifi
#
# Departure/Arrival       -> Rating for the departure
#
# Inflight Entertainment  -> Rating for Inflight entertainment
#
# On-Board services       -> Rating for Onboarding services
#
# Leg room services       -> Rating for leg room services
#
# Baggage Handling        -> Rating for Handling the Luggage
#
# Checkin Services        -> Rating for the Checkin process
#
# Inflight Services       -> Rating for the Inflight services
#
# Cleanliness             -> Rating for the Cleanliness
#
# Departure delay (mins)  -> Departure delay of flight in minutes
#
# Arrival delay (mins)    -> Arrival of flight in minutes
#
# Satisfaction            -> Overall satisfaction

# %%
ds2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25976 entries, 0 to 25975
# Data columns (total 24 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          25976 non-null  int64
#  1   Gender                      25976 non-null  object
#  2   Customer                    25976 non-null  object
#  3   Age                         25976 non-null  int64
#  4   Type                        25976 non-null  object
#  5   Class                       25976 non-null  object
#  6   Distance                    25976 non-null  int64
#  7   Wifi                        25976 non-null  int64
#  8   Departure                   25976 non-null  int64
#  9   Online                      25976 non-null  int64
#  10  Gate_location               25976 non-null  int64
#  11  Food_and_drink              25976 non-null  int64
#  12  Online_boarding             25976 non-null  int64
# ...

# %% [markdown]
# Information present in the Airline Passenger Satisfaction
#
# 1) In this dataset, we have 24 columns and 25975 rows which provides the information about the Airline Passengers Satisfaction report
#
# 2) Memory used is 4.8+MB

# %%
ds2.describe()
# Out:
#                   id           Age      Distance          Wifi     Departure  \
# count   25976.000000  25976.000000  25976.000000  25976.000000  25976.000000
# mean    65005.657992     39.620958   1193.788459      2.724746      3.046812
# std     37611.526647     15.135685    998.683999      1.335384      1.533371
# min        17.000000      7.000000     31.000000      0.000000      0.000000
# 25%     32170.500000     27.000000    414.000000      2.000000      2.000000
# 50%     65319.500000     40.000000    849.000000      3.000000      3.000000
# 75%     97584.250000     51.000000   1744.000000      4.000000      4.000000
# max    129877.000000     85.000000   4983.000000      5.000000      5.000000
#
#              Online  Gate_location  Food_and_drink  Online_boarding  \
# count  25976.000000   25976.000000    25976.000000     25976.000000
# mean       2.756775       2.977094        3.215353         3.261665
# std        1.412951       1.282133        1.331506         1.355536
# ...

# %% [markdown]
# **1) How many male passengers in economy class covered more than 500 kms?**

# %%
A = ds2[0:50][(ds1.Gender=='Male')& (ds2.Class=='Eco')&(ds2.Distance>=500)]
A
# Out:
# <ipython-input-23-4b99955a29b1>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   A = ds2[0:50][(ds1.Gender=='Male')& (ds2.Class=='Eco')&(ds2.Distance>=500)]
#        id Gender           Customer  Age             Type Class  Distance  \
# 8   27508   Male     Loyal Customer   47  Business travel   Eco       556
# 21  75855   Male     Loyal Customer   43  Personal Travel   Eco      1437
# 25   7823   Male     Loyal Customer   62  Personal Travel   Eco       710
# 32  70811   Male  disloyal Customer   41  Business travel   Eco       624
# 33  75241   Male     Loyal Customer   22  Personal Travel   Eco      1846
# 35  48372   Male     Loyal Customer   12  Personal Travel   Eco       674
# 41  16112   Male  disloyal Customer   24  Business travel   Eco       725
#
#     Wifi  Departure  Online  ...  Entertainment  Onboard_service  \
# 8      5          2       2  ...              5                2
# ...

# %% [markdown]
# **Male passenger above the age of 50 and also travelled distance more than 500 kms in flight**

# %% [markdown]
#  **2) How much Business Travel passengers prefer Economy class**

# %%
B = ds2[15:40][(ds2.Type=='Business travel')&(ds2.Class=='Eco')]
B
# Out:
# <ipython-input-24-b041ae61a505>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   B = ds2[15:40][(ds2.Type=='Business travel')&(ds2.Class=='Eco')]
#         id  Gender           Customer  Age             Type Class  Distance  \
# 16  124915  Female     Loyal Customer   31  Business travel   Eco       728
# 24   82602  Female  disloyal Customer   30  Business travel   Eco       528
# 27   34501  Female     Loyal Customer   22  Business travel   Eco      1521
# 29   20219    Male     Loyal Customer   51  Business travel   Eco       235
# 31   48994  Female     Loyal Customer   56  Business travel   Eco       308
# 32   70811    Male  disloyal Customer   41  Business travel   Eco       624
# 34   12312  Female     Loyal Customer   53  Business travel   Eco       192
#
#     Wifi  Departure  Online  ...  Entertainment  Onboard_service  \
# 16     2          5       5  ...              2                4
# ...

# %% [markdown]
# **Persons who are travelling for business purpose and also perferring the economy class most of the time**

# %% [markdown]
# **3) How many female passengers are above 35 and using the business class**

# %%
C = ds2[50:125][(ds2.Gender=='Female')&(ds2.Age>=35)&(ds2.Class=='Business')]
C
# Out:
# <ipython-input-25-0625edea10f1>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   C = ds2[50:125][(ds2.Gender=='Female')&(ds2.Age>=35)&(ds2.Class=='Business')]
#          id  Gender           Customer  Age             Type     Class  \
# 68    87976  Female     Loyal Customer   42  Business travel  Business
# 69    31640  Female     Loyal Customer   41  Business travel  Business
# 70    41461  Female     Loyal Customer   53  Personal Travel  Business
# 72    78136  Female     Loyal Customer   54  Personal Travel  Business
# 80    58576  Female     Loyal Customer   61  Business travel  Business
# 87   102623  Female     Loyal Customer   50  Business travel  Business
# 94   119896  Female     Loyal Customer   46  Business travel  Business
# 99    61426  Female  disloyal Customer   40  Business travel  Business
# 112   88237  Female     Loyal Customer   45  Business travel  Business
#
# ...

# %% [markdown]
# **Female passengers aged above 35 and also using the business class for travelling**

# %% [markdown]
# **4) How many passengers are aged above 25?**

# %%
D = ds2[ds2['Age']>25]
print("Total:",D.id.nunique())
# Out:
# Total: 20416

# %% [markdown]
# **Passengers aged above 25 are nearly 20416 of them**

# %% [markdown]
# **5) Bar chart for the Cleanliness rating**

# %%
ds2['Cleanliness'].value_counts().plot(kind='bar',color=['red','purple','yellow','orange','pink'],width=0.4);
#plt.legend(loc="upper right")
plt.suptitle('Data Analysis of Airplane Satisfaction')
#plt.title('Cleanliness')
plt.xlabel('Ratings ')
plt.ylabel('Passengers')
plt.show()

# %% [markdown]
# **6) How many personal travel clients are our loyal customers**

# %%
ds2.loc[15:51, 'id':'Type'][(ds2.Type=='Personal Travel')&(ds2.Customer=='Loyal Customer')]
# Out:
# <ipython-input-28-87ba5625ead8>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   ds2.loc[15:51, 'id':'Type'][(ds2.Type=='Personal Travel')&(ds2.Customer=='Loyal Customer')]
#         id  Gender        Customer  Age             Type
# 15   22470    Male  Loyal Customer   50  Personal Travel
# 17   17836    Male  Loyal Customer   52  Personal Travel
# 18   76872  Female  Loyal Customer   43  Personal Travel
# 21   75855    Male  Loyal Customer   43  Personal Travel
# 22  106181    Male  Loyal Customer   55  Personal Travel
# 25    7823    Male  Loyal Customer   62  Personal Travel
# 30   67551    Male  Loyal Customer   43  Personal Travel
# 33   75241    Male  Loyal Customer   22  Personal Travel
# 35   48372    Male  Loyal Customer   12  Personal Travel
# 39  101991  Female  Loyal Customer   40  Personal Travel
# 47   96283  Female  Loyal Customer   59  Personal Travel
# 49   74703  Female  Loyal Customer   44  Personal Travel
# ...

# %% [markdown]
# **Passengers who are Loyal customers and also using flight for personal travel**

# %% [markdown]
# **7) How much rating we got for depature using pie chart**

# %%
ds2['Departure'].value_counts().plot(kind='pie');
plt.legend(loc="lower right")
plt.suptitle('Data Analysis of Airplane Satisfaction')
#plt.title('Cleanliness')
plt.xlabel('Ratings ')
plt.show()

# %% [markdown]
# **Pie chart analysis of the Ceparture/Arrival time convenient**

# %% [markdown]
# **8) Creating a line graph for male and female passengers**

# %%
ds2
# Out:
#           id  Gender           Customer  Age             Type     Class  \
# 0      19556  Female     Loyal Customer   52  Business travel       Eco
# 1      90035  Female     Loyal Customer   36  Business travel  Business
# 2      12360    Male  disloyal Customer   20  Business travel       Eco
# 3      77959    Male     Loyal Customer   44  Business travel  Business
# 4      36875  Female     Loyal Customer   49  Business travel       Eco
# ...      ...     ...                ...  ...              ...       ...
# 25971  78463    Male  disloyal Customer   34  Business travel  Business
# 25972  71167    Male     Loyal Customer   23  Business travel  Business
# 25973  37675  Female     Loyal Customer   17  Personal Travel       Eco
# 25974  90086    Male     Loyal Customer   14  Business travel  Business
# 25975  34799  Female     Loyal Customer   42  Personal Travel       Eco
#
#        Distance  Wifi  Departure  Online  ...  Entertainment  Onboard_service  \
# ...

# %% [markdown]
# **9) Plot Kernel Density Estimation of Age**

# %%
ds2.groupby('Gender').Age.plot(kind='kde')
plt.title('Kernel Density estimation of Age')
plt.xlabel('AGE')
plt.ylabel('Probability Density')
plt.show()

# %% [markdown]
# **10) Finding the number of Males and Females in the Dataset using sum**

# %%
num = (ds2.Gender=='Female').sum()
print("Number of females in the dataset is :",num);
num1 = (ds2.Gender=='Male').sum()
print("Number of males in the dataset is :",num1);
# Out:
# Number of females in the dataset is : 13172
# Number of males in the dataset is : 12804

# %% [markdown]
# **Total number of Male and Female passengers in the dataset**
#
# **Male - 13172** , **Female - 12804**

# %% [markdown]
# **11) Pie chart for the Male and Female in the Airplane Passenger Satisfaction dataset**

# %%
ds2['Gender'].value_counts().plot(kind='bar',y={num,num1},width=0.2,color={'red','blue'});
plt.suptitle('Pie chart for the Gender')
plt.title('Gender')
plt.show()
